# %% [raw]
# import pandas as pd
# import warnings
# warnings.filterwarnings('ignore')
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np

# %%
df=pd.read_csv(r"C:\Users\umadevi\Downloads\archive (1).zip")
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
# Checking data types of features

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
# Calculating descriptive statistics of catcategorical  feature

df.describe(include='O')
# Out:
#          DATE_DIED
# count      1048575
# unique         401
# top     9999-99-99
# freq        971633

# %%
# Calculating descriptive statistics of numerical features

df.describe(exclude='O')
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
# Checking number of missing values in each feature

df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
# Assigned the value 0 for the people who are dead and 1 for the people who are not dead

def died(row):
    if row == '9999-99-99':
        return 1 
    else:
        return 0 
df['DIED'] = df.DATE_DIED.apply(died)
df.drop('DATE_DIED',axis=1,inplace=True)

# %%
# Checking the number of identical records
df.duplicated().sum()
# Out:
# 836562

# %%
df[1048570:1048573]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 1048570      2            13    2             1       97          2   40
# 1048571      1            13    2             2        2          2   51
# 1048572      2            13    2             1       97          2   55
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 1048570        97         2     2  ...        2             2              2
# 1048571        97         2     2  ...        2             1              2
# 1048572        97         2     2  ...        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 1048570               2        2              2        2
# 1048571               2        2              2        2
# 1048572               2        2              2        2
#
#          CLASIFFICATION_FINAL  ICU  DIED
# 1048570                     7   97     1
# 1048571                     7    2     1
# ...

# %%
df[1048573:1048576]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 1048573      2            13    2             1       97          2   28
# 1048574      2            13    2             1       97          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 1048573        97         2     2  ...        2             2              2
# 1048574        97         2     2  ...        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 1048573               2        2              2        2
# 1048574               2        2              2        2
#
#          CLASIFFICATION_FINAL  ICU  DIED
# 1048573                     7   97     1
# 1048574                     7   97     1
#
# [2 rows x 21 columns]

# %%
# Dropping duplicated rows
df = df.drop_duplicates()
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0            2             1    1             1       97          1   65
# 1            2             1    2             1       97          1   72
# 2            2             1    2             2        1          2   55
# 3            2             1    1             1       97          2   53
# 4            2             1    2             1       97          2   68
# ...        ...           ...  ...           ...      ...        ...  ...
# 1048568      1            13    2             1       97          2   47
# 1048569      1            13    1             2        2          2   56
# 1048571      1            13    2             2        2          2   51
# 1048572      2            13    2             1       97          2   55
# 1048574      2            13    2             1       97          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Resetting index
df.reset_index(drop=True, inplace=True)
df
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 212008      1            13    2             1       97          2   47
# 212009      1            13    1             2        2          2   56
# 212010      1            13    2             2        2          2   51
# 212011      2            13    2             1       97          2   55
# 212012      2            13    2             1       97          2   52
#
#         PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df.loc[(df["HIPERTENSION"]==1)& (df["AGE"]>=50),['HIPERTENSION']].count()
# Out:
# HIPERTENSION    58801
# dtype: int64

# %%
# patients returned home wrt age
df = df[df['PATIENT_TYPE']==1.0]
df.groupby('PATIENT_TYPE').AGE.value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='PATIENT_TYPE,AGE'>

# %%
# plotting each feature
df.hist(figsize=(20,20));

# %%
plt.figure(figsize=(10,5))
sns.histplot(x=df.AGE,hue=df.DIED,kde=True).set(title='Number of survivors and deaths by age')
# Out:
# [Text(0.5, 1.0, 'Number of survivors and deaths by age')]

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='SEX', hue='DIED',)
plt.title('Number of deaths wrt gener', fontsize=20)
plt.ylabel('Count')
plt.xlabel('Genre')
plt.xticks([0, 1], ['Women', 'Men']);

# %%
sns.countplot(hue=df.DIED, x= df.MEDICAL_UNIT);
